# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanush777max/ADM/blob/main/LAB_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from sklearn.decomposition import PCA

from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

df = pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data = pd.read_csv("Iris.csv")

# %%
numerical_features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']  # Assuming these are your numerical columns
numerical_data = data[numerical_features]

# %%
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(numerical_data)

# %%
pca = PCA(n_components=2)

# %%
reduced_data = pca.fit_transform(scaled_data)

# %%
species_mapping = {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}
color_indices = data['Species'].map(species_mapping)

# %%
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], c=color_indices)
plt.xlabel("PC 1")
plt.ylabel("PC 2")
plt.title("PCA Visualization")
plt.show()

# %%
data1 = pd.read_csv("Iris.csv")
numerical_features = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
numerical_data = data[numerical_features]

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical_data)

# %%
pca = PCA(n_components=3)
reduced_data = pca.fit_transform(scaled_data)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

species_mapping = {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}
color_indices = data['Species'].map(species_mapping)

ax.scatter(reduced_data[:, 0], reduced_data[:, 1], reduced_data[:, 2], c=color_indices)

ax.set_xlabel("PC 1")
ax.set_ylabel("PC 2")
ax.set_zlabel("PC 3")
ax.set_title("PCA Visualization (3 Components)")
plt.show()
